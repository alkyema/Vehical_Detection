# %%
#!pip install ultralytics

# %%
import ultralytics
ultralytics.__version__
# Out:
# '8.3.98'

# %%
# !cd
# Out:
# c:\Users\satwi\Downloads\Vehical detection

# %%
import cv2
import pandas as pd
from ultralytics import YOLO
from tracker import*

model=YOLO('yolov8s.pt')
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8s.pt to 'yolov8s.pt'...
# 100%|██████████| 21.5M/21.5M [00:06<00:00, 3.25MB/s]

# %%
class_list = ['person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus', 'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed', 'dining table', 'toilet', 'tv', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush']

# %%
tracker=Tracker()
count=0

# %%
cap=cv2.VideoCapture('2.mp4')

# %%
down={}
up={}

counter_down=[]
counter_up=[]

# %%
while True:    
    ret,frame = cap.read()
    if not ret:
        break
    count += 1
    frame=cv2.resize(frame,(1020,500))
   

    results=model.predict(frame)
 #   print(results)
    a=results[0].boxes.data
    a = a.detach().cpu().numpy()  # added this line
    px=pd.DataFrame(a).astype("float")
    #print(px)

    list=[]
             
    for index,row in px.iterrows():
#        print(row) 
        x1=int(row[0])
        y1=int(row[1])
        x2=int(row[2])
        y2=int(row[3])
        d=int(row[5])
        c=class_list[d]
        if 'car' in c:
            list.append([x1,y1,x2,y2])
            #print(c)

    bbox_id=tracker.update(list)
    #print(bbox_id)
    for bbox in bbox_id:
        x3,y3,x4,y4,id=bbox
        cx=int(x3+x4)//2
        cy=int(y3+y4)//2

        red_line_y=198
        blue_line_y=268   
        offset = 7
        
  

        ''' both lines combined condition . First condition is for red line'''
        ## condition for counting the cars which are entering from red line and exiting from blue line
        if red_line_y < (cy + offset) and red_line_y > (cy - offset):
          down[id]=cy   
        if id in down:
           if blue_line_y < (cy + offset) and blue_line_y > (cy - offset):         
             cv2.circle(frame,(cx,cy),4,(0,0,255),-1)
             cv2.putText(frame,str(id),(cx,cy),cv2.FONT_HERSHEY_COMPLEX,0.8,(0,255,255),2)
             #counter+=1
             counter_down.append(id)  # get a list of the cars and buses which are entering the line red and exiting the line blue

        # condition for cars entering from  blue line
        if blue_line_y < (cy + offset) and blue_line_y > (cy - offset):
          up[id]=cy   
        if id in up:
           if red_line_y < (cy + offset) and red_line_y > (cy - offset):         
             cv2.circle(frame,(cx,cy),4,(0,0,255),-1)
             cv2.putText(frame,str(id),(cx,cy),cv2.FONT_HERSHEY_COMPLEX,0.8,(0,255,255),2)
             #counter+=1
             counter_up.append(id)  # get a list of the cars which are entering the line 1 and exiting the line 2 




    
    text_color = (255,255,255)  # white color for text
    red_color = (0, 0, 255)  # (B, G, R)   
    blue_color = (255, 0, 0)  # (B, G, R)
    green_color = (0, 255, 0)  # (B, G, R)  

    cv2.line(frame,(172,198),(774,198),red_color,3)  #  starting cordinates and end of line cordinates
    cv2.putText(frame,('red line'),(172,198),cv2.FONT_HERSHEY_SIMPLEX, 0.5, text_color, 1, cv2.LINE_AA)
    
    cv2.line(frame,(8,268),(927,268),blue_color,3)  # seconde line
    cv2.putText(frame,('blue line'),(8,268),cv2.FONT_HERSHEY_SIMPLEX, 0.5, text_color, 1, cv2.LINE_AA)    


    downwards = (len(counter_down))
    cv2.putText(frame,('going down - ')+ str(downwards),(60,40),cv2.FONT_HERSHEY_SIMPLEX, 0.5, green_color, 1, cv2.LINE_AA)    

    
    upwards = (len(counter_up))
    cv2.putText(frame,('going up - ')+ str(upwards),(60,60),cv2.FONT_HERSHEY_SIMPLEX, 0.5, text_color, 1, cv2.LINE_AA)  

    cv2.imshow("frames", frame)
    if cv2.waitKey(1)&0xFF==27:
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 320x640 8 cars, 2 trucks, 63.8ms
# Speed: 4.3ms preprocess, 63.8ms inference, 639.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 35.4ms
# Speed: 6.6ms preprocess, 35.4ms inference, 6.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 15.2ms
# Speed: 2.7ms preprocess, 15.2ms inference, 3.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck,
1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 1 truck, 25.8ms
# Speed: 5.1ms preprocess, 25.8ms inference, 4.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 1 truck, 18.5ms
# Speed: 3.0ms preprocess, 18.5ms inference, 5.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 1 truck, 12.1ms
# Speed: 2.0ms preprocess, 12.1ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 1 truck, 8.5ms
# Speed: 1.5ms preprocess, 8.5ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 7.9ms
# Speed: 1.4ms preprocess, 7.9ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 9.1ms
# Speed: 1.8ms preprocess, 9.1ms inference, 4.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 7.4ms
# Speed: 1.8ms preprocess, 7.4ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 6.8ms
# Speed: 1.3ms preprocess, 6.8ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 1 truck, 9.0ms
# Speed: 1.7ms preprocess, 9.0ms inference, 3.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 1 truck, 9.6ms
# Speed: 1.8ms preprocess, 9.6ms inference, 3.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 1 truck, 8.7ms
# Speed: 1.8ms preprocess, 8.7ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 1 truck, 9.4ms
# Speed: 1.5ms preprocess, 9.4ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 1 truck, 11.6ms
# Speed: 2.0ms preprocess, 11.6ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 168.9ms
# Speed: 6.2ms preprocess, 168.9ms inference, 35.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 36.7ms
# Speed: 6.5ms preprocess, 36.7ms inference, 6.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 20.8ms
# Speed: 3.3ms preprocess, 20.8ms inference, 5.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 10.9ms
# Speed: 2.6ms preprocess, 10.9ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 9.2ms
# Speed: 1.8ms preprocess, 9.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 11.8ms
# Speed: 1.9ms preprocess, 11.8ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 10.1ms
# Speed: 1.7ms preprocess, 10.1ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 39.2ms
# Speed: 4.4ms preprocess, 39.2ms inference, 5.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 8.6ms
# Speed: 1.6ms preprocess, 8.6ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 13.5ms
# Speed: 2.0ms preprocess, 13.5ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 14.1ms
# Speed: 2.3ms preprocess, 14.1ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 158.1ms
# Speed: 7.6ms preprocess, 158.1ms inference, 32.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 32.6ms
# Speed: 5.3ms preprocess, 32.6ms inference, 5.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 22.5ms
# Speed: 3.4ms preprocess, 22.5ms inference, 4.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 1 truck, 12.9ms
# Speed: 2.7ms preprocess, 12.9ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 11.4ms
# Speed: 2.0ms preprocess, 11.4ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 11.0ms
# Speed: 1.8ms preprocess, 11.0ms inference, 3.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 10.7ms
# Speed: 1.5ms preprocess, 10.7ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 7.9ms
# Speed: 1.5ms preprocess, 7.9ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 9.1ms
# Speed: 1.3ms preprocess, 9.1ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 1 truck, 11.9ms
# Speed: 1.7ms preprocess, 11.9ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 1 truck, 12.5ms
# Speed: 2.5ms preprocess, 12.5ms inference, 3.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 1 truck, 15.5ms
# Speed: 3.2ms preprocess, 15.5ms inference, 3.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 155.8ms
# Speed: 16.4ms preprocess, 155.8ms inference, 24.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 31.2ms
# Speed: 5.1ms preprocess, 31.2ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 21.2ms
# Speed: 3.5ms preprocess, 21.2ms inference, 4.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 11.5ms
# Speed: 2.2ms preprocess, 11.5ms inference, 3.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 10.2ms
# Speed: 2.0ms preprocess, 10.2ms inference, 3.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 10.6ms
# Speed: 1.6ms preprocess, 10.6ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 7.3ms
# Speed: 1.5ms preprocess, 7.3ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 8.3ms
# Speed: 1.3ms preprocess, 8.3ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 7.4ms
# Speed: 1.6ms preprocess, 7.4ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 9.6ms
# Speed: 1.6ms preprocess, 9.6ms inference, 3.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 10.9ms
# Speed: 1.7ms preprocess, 10.9ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 8.6ms
# Speed: 1.5ms preprocess, 8.6ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 9.1ms
# ...
#
# 0: 320x640 3 cars, 14.7ms
# Speed: 1.6ms preprocess, 14.7ms inference, 3.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 13.4ms
# Speed: 1.6ms preprocess, 13.4ms inference, 3.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 12.3ms
# Speed: 1.9ms preprocess, 12.3ms inference, 3.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 10.2ms
# Speed: 1.7ms preprocess, 10.2ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 142.1ms
# Speed: 4.1ms preprocess, 142.1ms inference, 32.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 39.6ms
# Speed: 8.3ms preprocess, 39.6ms inference, 5.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 28.8ms
# Speed: 3.9ms preprocess, 28.8ms inference, 4.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 13.1ms
# Speed: 2.2ms preprocess, 13.1ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 10.7ms
# Speed: 1.6ms preprocess, 10.7ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 1 truck, 8.5ms
# Speed: 1.5ms preprocess, 8.5ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 1 truck, 9.6ms
# Speed: 1.4ms preprocess, 9.6ms inference, 3.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 1 truck, 12.9ms
# Speed: 1.8ms preprocess, 12.9ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 1 truck, 13.2ms
# Speed: 2.1ms preprocess, 13.2ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 11.3ms
# Speed: 1.9ms preprocess, 11.3ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 22.4ms
# Speed: 3.5ms preprocess, 22.4ms inference, 6.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 167.3ms
# Speed: 23.4ms preprocess, 167.3ms inference, 7.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 27.6ms
# Speed: 3.8ms preprocess, 27.6ms inference, 4.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 20.3ms
# Speed: 5.2ms preprocess, 20.3ms inference, 6.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 1 truck, 12.6ms
# Speed: 1.9ms preprocess, 12.6ms inference, 3.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 10.5ms
# Speed: 1.6ms preprocess, 10.5ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 11.4ms
# Speed: 1.8ms preprocess, 11.4ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 1 truck, 11.6ms
# Speed: 1.5ms preprocess, 11.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 28.4ms
# Speed: 2.1ms preprocess, 28.4ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 13.8ms
# Speed: 1.6ms preprocess, 13.8ms inference, 3.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 3 trucks, 13.1ms
# Speed: 2.0ms preprocess, 13.1ms inference, 4.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 2 trucks, 19.4ms
# Speed: 2.3ms preprocess, 19.4ms inference, 4.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 2 trucks, 215.2ms
# Speed: 47.0ms preprocess, 215.2ms inference, 10.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 2 trucks, 29.4ms
# Speed: 3.6ms preprocess, 29.4ms inference, 5.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 2 trucks, 24.6ms
# Speed: 2.7ms preprocess, 24.6ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car, 2 trucks, 12.5ms
# Speed: 1.9ms preprocess, 12.5ms inference, 3.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 2 trucks, 11.9ms
# Speed: 2.1ms preprocess, 11.9ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car, 2 trucks, 11.7ms
# Speed: 1.6ms preprocess, 11.7ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car, 1 bus, 2 trucks, 8.6ms
# Speed: 1.5ms preprocess, 8.6ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car, 1 truck, 10.4ms
# Speed: 1.5ms preprocess, 10.4ms inference, 3.9ms postprocess per image at shape (1, 3, 320, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 9
#       5    count += 1
#       6    frame=cv2.resize(frame,(1020,500))
# ----> 9    results=model.predict(frame)
#      10 #   print(results)
#      11    a=results[0].boxes.data
#
# File c:\Users\satwi\.conda\envs\torch_cuda\lib\site-packages\ultralytics\engine\model.py:550, in Model.predict(self, source, stream, predictor, **kwargs)
#     548 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     549     self.predictor.set_prompts(prompts)
# --> 550 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File c:\Users\satwi\.conda\envs\torch_cuda\lib\site-packages\ultralytics\engine\predictor.py:214, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     212     return self.stream_inference(source, model, *args, **kwargs)
#     213 else:
# --> 214     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File c:\Users\satwi\.conda\envs\torch_cuda\lib\site-packages\torch\utils\_contextlib.py:36, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      33 try:
#      34     # Issuing `None` to a generator fires it up
#      35     with ctx_factory():
# ---> 36         response = gen.send(None)
#      38     while True:
#      39         try:
#      40             # Forward the response to our caller and get its next request
#
# File c:\Users\satwi\.conda\envs\torch_cuda\lib\site-packages\ultralytics\engine\predictor.py:323, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     321 # Inference
#     322 with profilers[1]:
# --> 323     preds = self.inference(im, *args, **kwargs)
#     324     if self.args.embed:
#     325         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File c:\Users\satwi\.conda\envs\torch_cuda\lib\site-packages\ultralytics\engine\predictor.py:171, in BasePredictor.inference(self, im, *args, **kwargs)
#     165 """Run inference on a given image using the specified model and arguments."""
#     166 visualize = (
#     167     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     168     if self.args.visualize and (not self.source_type.tensor)
#     169     else False
#     170 )
# --> 171 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File c:\Users\satwi\.conda\envs\torch_cuda\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\satwi\.conda\envs\torch_cuda\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\satwi\.conda\envs\torch_cuda\lib\site-packages\ultralytics\nn\autobackend.py:570, in AutoBackend.forward(self, im, augment, visualize, embed)
#     568 # PyTorch
#     569 if self.pt or self.nn_module:
# --> 570     y = self.model(im, augment=augment, visualize=visualize, embed=embed)
#     572 # TorchScript
#     573 elif self.jit:
#
# File c:\Users\satwi\.conda\envs\torch_cuda\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\satwi\.conda\envs\torch_cuda\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\satwi\.conda\envs\torch_cuda\lib\site-packages\ultralytics\nn\tasks.py:114, in BaseModel.forward(self, x, *args, **kwargs)
#     112 if isinstance(x, dict):  # for cases of training and validating while training.
#     113     return self.loss(x, *args, **kwargs)
# --> 114 return self.predict(x, *args, **kwargs)
#
# File c:\Users\satwi\.conda\envs\torch_cuda\lib\site-packages\ultralytics\nn\tasks.py:132, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     130 if augment:
#     131     return self._predict_augment(x)
# --> 132 return self._predict_once(x, profile, visualize, embed)
#
# File c:\Users\satwi\.conda\envs\torch_cuda\lib\site-packages\ultralytics\nn\tasks.py:153, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     151 if profile:
#     152     self._profile_one_layer(m, x, dt)
# --> 153 x = m(x)  # run
#     154 y.append(x if m.i in self.save else None)  # save output
#     155 if visualize:
#
# File c:\Users\satwi\.conda\envs\torch_cuda\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\satwi\.conda\envs\torch_cuda\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\satwi\.conda\envs\torch_cuda\lib\site-packages\ultralytics\nn\modules\block.py:301, in C2f.forward(self, x)
#     299 """Forward pass through C2f layer."""
#     300 y = list(self.cv1(x).chunk(2, 1))
# --> 301 y.extend(m(y[-1]) for m in self.m)
#     302 return self.cv2(torch.cat(y, 1))
#
# File c:\Users\satwi\.conda\envs\torch_cuda\lib\site-packages\ultralytics\nn\modules\block.py:301, in <genexpr>(.0)
#     299 """Forward pass through C2f layer."""
#     300 y = list(self.cv1(x).chunk(2, 1))
# --> 301 y.extend(m(y[-1]) for m in self.m)
#     302 return self.cv2(torch.cat(y, 1))
#
# File c:\Users\satwi\.conda\envs\torch_cuda\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\satwi\.conda\envs\torch_cuda\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\satwi\.conda\envs\torch_cuda\lib\site-packages\ultralytics\nn\modules\block.py:476, in Bottleneck.forward(self, x)
#     474 def forward(self, x):
#     475     """Apply bottleneck with optional shortcut connection."""
# --> 476     return x + self.cv2(self.cv1(x)) if self.add else self.cv2(self.cv1(x))
#
# File c:\Users\satwi\.conda\envs\torch_cuda\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\satwi\.conda\envs\torch_cuda\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\satwi\.conda\envs\torch_cuda\lib\site-packages\ultralytics\nn\modules\conv.py:91, in Conv.forward_fuse(self, x)
#      81 def forward_fuse(self, x):
#      82     """
#      83     Apply convolution and activation without batch normalization.
#      84
#    (...)
#      89         (torch.Tensor): Output tensor.
#      90     """
# ---> 91     return self.act(self.conv(x))
#
# File c:\Users\satwi\.conda\envs\torch_cuda\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\satwi\.conda\envs\torch_cuda\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\satwi\.conda\envs\torch_cuda\lib\site-packages\torch\nn\modules\conv.py:554, in Conv2d.forward(self, input)
#     553 def forward(self, input: Tensor) -> Tensor:
# --> 554     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\Users\satwi\.conda\envs\torch_cuda\lib\site-packages\torch\nn\modules\conv.py:549, in Conv2d._conv_forward(self, input, weight, bias)
#     537 if self.padding_mode != "zeros":
#     538     return F.conv2d(
#     539         F.pad(
#     540             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)
#     547         self.groups,
#     548     )
# --> 549 return F.conv2d(
#     550     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551 )
#
# KeyboardInterrupt:
